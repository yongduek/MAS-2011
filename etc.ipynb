# %%
import scipy.stats as stats
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
def hinv(th):
    return 2 - 4*th - 2*th*th

# %%
th = np.linspace(0,1,1000)
s2 = hinv(th)
plt.plot(th, s2)

# %%
hinv(1/3.)
# Out:
# 0.44444444444444453

# %%
X = stats.uniform(0,1).rvs(100)

# %%
sns.displot(X);

# %%
Nx, Ny = 1000, 1000
ys = np.zeros((Nx, Ny))
for i in range(Nx):
    x = stats.uniform(0,1).rvs()
    y = stats.uniform(0,x).rvs(Ny)
    ys[i] = y 
Y = ys.reshape(-1)

# %%
sns.displot(Y)

# %%
np.log(.5) + 1
# Out:
# 0.3068528194400547

# %%
y = np.linspace(0.001,.999,100)
plt.plot(y, -y*np.log(y))

# %%
a = 2/(8**2)
b = 3 / (10 **2)
pa = a / (a+b)
pa
# Out:
# 0.5102040816326531

# %%
25/49
# Out:
# 0.5102040816326531

# %%
j = np.array([ .3**3 * .7, .2*.5**3, .5 * .6**2 * .4])
p = j / j.sum()
p
# Out:
# array([0.16307161, 0.21570319, 0.62122519])

# %%
j.sum()
# Out:
# 0.11589999999999999

# %%
.875*.1 / (.875*.1 + .025 * .9)
# Out:
# 0.7954545454545454

# %%
.125*.1/(.125*.1+.975*.9)
# Out:
# 0.014044943820224722

# %%
np.array([[1,2],[1,1]]) @ np.array([[-1, 2], [1, -1]])
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
M = np.array([[-1, 2], [1, -1]])
CXY = np.array([[4, -3], [-3, 9]])

M @ CXY @ M.T
# Out:
# array([[ 52, -31],
#        [-31,  19]])

# %%
28*7 - 13*13
# Out:
# 27

# %%
def h(th):
    return 2 / (th**2)

# %%
def getRegularPolygon(N, radius=1):
    v = np.zeros((N,2))
    for i in range(N):
        deg = i * 360. / N
        rad = deg * np.pi / 360.
        x = radius * np.cos(rad)
        y = radius * np.sin(rad)
        v[i] = [x, y]
    return v


color = np.random.randint(0, 255, size=(3))
color = np.array([255, 128, 200])
print(color.shape, color.dtype, color)
nvertices = 3 #np.random.randint(3, 10)
poly = getRegularPolygon(nvertices, radius=100)
poly
# Out:
# (3,) int32 [255 128 200]
# array([[100.        ,   0.        ],
#        [ 50.        ,  86.60254038],
#        [-50.        ,  86.60254038]])

# %%
txy = np.array([[0, 200]])

poly + txy
# Out:
# array([[100.        , 200.        ],
#        [ 50.        , 286.60254038],
#        [-50.        , 286.60254038]])

# %%
txy = np.array([0, 200])

poly + txy
# Out:
# array([[100.        , 200.        ],
#        [ 50.        , 286.60254038],
#        [-50.        , 286.60254038]])

# %%
q = poly.copy()
for n in range(poly.shape[0]):
    for i in range(2):
        q[n, i] += txy[i]
q
# Out:
# array([[100.        , 200.        ],
#        [ 50.        , 286.60254038],
#        [-50.        , 286.60254038]])

# %%
N = 4
v = np.zeros((N,2), dtype=np.float32)

# %%
v, v.shape
# Out:
# (array([[0., 0.],
#         [0., 0.],
#         [0., 0.],
#         [0., 0.]], dtype=float32),
#  (4, 2))

# %%
def getRegularPolygon(N, radius=1):
    v = np.zeros((N,2), dtype=np.float32)
    for i in range(N):
        deg = i * 360. / N
        rad = deg * np.pi / 180.
        x = radius * np.cos(rad)
        y = radius * np.sin(rad)
        v[i, 0] = x 
        v[i, 1] = y 
    return v

# %%
rect = getRegularPolygon(4)
rect
# Out:
# array([[ 1.0000000e+00,  0.0000000e+00],
#        [ 6.1232343e-17,  1.0000000e+00],
#        [-1.0000000e+00,  1.2246469e-16],
#        [-1.8369701e-16, -1.0000000e+00]], dtype=float32)

# %%
r2 = rect * 100
r2
# Out:
# array([[ 1.0000000e+02,  0.0000000e+00],
#        [ 6.1232342e-15,  1.0000000e+02],
#        [-1.0000000e+02,  1.2246468e-14],
#        [-1.8369702e-14, -1.0000000e+02]], dtype=float32)

# %%
txy = np.array([[100, 200]])

# %%
r2 + txy
# Out:
# array([[200., 200.],
#        [100., 300.],
#        [  0., 200.],
#        [100., 100.]])

# %%
r2.shape, txy.shape
# Out:
# ((4, 2), (1, 2))

# %%
color = np.random.randint(0, 256, size=3)
color
# Out:
# array([ 24, 132, 208])
